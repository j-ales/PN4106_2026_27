# %% [markdown]
# # Week 1 answers: JupyterLab and Python basics
#
# This notebook gives example answers and explanations for the week-one exercises. Answers involving personal choices, such as a name or favourite snacks, will naturally differ.

# %% [markdown]
# ## 1. Check your JupyterHub workspace
#
# There is no code answer for this section. You should be able to find the notebook in the file browser, rename your working copy, and save it. If you cannot do one of these things, ask for help.

# %% [markdown]
# ## 2. Edit a Markdown cell
#
# An example completed Markdown cell is shown below.
#
# ### Student: Alex Smith
#
# I am working in JupyterLab for the first time on: 17 September 2026
#
# Your name and date should replace these examples. The `###` symbols create a small heading when the Markdown cell is run.

# %% [markdown]
# ## 3. Run and edit Python code
#
# The supplied environment-check cell should print a message beneath the cell. A personalised message could look like this:

# %%
print("I have run my first Python code cell.")

# %% [markdown]
# The quotation marks tell Python that the content is text. The parentheses contain the value being given to the `print()` function.

# %% [markdown]
# ## 4. Arithmetic

# %%
# Add 5 and 3
5 + 3

# %%
# Multiply 4 by 2
4 * 2

# %%
# Subtract 6 from 15
15 - 6

# %% [markdown]
# The expected outputs are `8`, `8`, and `9`. The final expression in a code cell is displayed automatically.

# %% [markdown]
# ## 5. Variables
#
# Here is one possible solution. Your name and number of available hours may be different.

# %%
student_name = "Alex"
week_number = 1
hours_available = 2.5

# %% [markdown]
# The assignment operator `=` stores each value under the name on its left. Text needs quotation marks; numeric values do not.

# %%
print(student_name)
print(week_number)
print(hours_available)

# %% [markdown]
# We pass each variable to `print()` by placing its name inside the parentheses. Do not put quotation marks around the variable name: `print("student_name")` would print the literal text rather than the value stored in the variable.

# %%
print(type(student_name))
print(type(week_number))
print(type(hours_available))

# %% [markdown]
# The types are `str`, `int`, and `float`. A string is text, an integer is a whole number, and a float is a number containing a decimal point.

# %% [markdown]
# ## 6. Lists
#
# Here is one possible list. The square brackets create the list, commas separate its items, and quotation marks identify each item as text.

# %%
snacks = ["apple", "popcorn", "chocolate"]
print(snacks)

# %% [markdown]
# Python starts counting list positions at zero, so `[0]` selects the first item.

# %%
print(snacks[0])

# %% [markdown]
# The index `-1` selects the final item without requiring us to know how long the list is.

# %%
print(snacks[-1])

# %% [markdown]
# The `len()` function returns the number of items. This list initially contains three items.

# %%
print(len(snacks))

# %% [markdown]
# The `.append()` method adds one item to the end of the existing list. After appending `"crisps"`, the list contains four items.

# %%
snacks.append("crisps")
print(snacks)
print(len(snacks))

# %% [markdown]
# A common mistake is to write `snacks[1]` when trying to obtain the first item. Index `1` is the second item because counting begins at zero.

# %% [markdown]
# ## 7. Fix a small mistake
#
# The word `finished` is text, so it needs quotation marks. Without them, Python treats `finished` as the name of a variable and reports that the name has not been defined.

# %%
status = "finished"
print(status)

# %% [markdown]
# ## 8. Check that your work persists
#
# Your message can contain any date or identifying note that helps you recognise the saved edit. For example:

# %%
persistence_message = "I saved this notebook on 17 September 2026."
print(persistence_message)

# %% [markdown]
# After saving, closing, and reopening the notebook, the edited cell should still contain your message. This confirms that the file was saved in your persistent JupyterHub workspace.

# %% [markdown]
# ## Finished
#
# Do not worry if the syntax does not yet feel automatic. The important week-one achievements are gaining access to the environment, saving your work, running cells, and beginning to recognise variables, types, and lists. These ideas will be reinforced throughout PN4106.
