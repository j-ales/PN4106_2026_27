# %% [markdown]
# # Week 1 exercises: JupyterLab and Python basics
#
# This is a gentle introduction to the environment and to a few pieces of Python. Work from top to bottom. Ask for help whenever you need it.
#
# There is a separate answers notebook, but try each task yourself before consulting it.

# %% [markdown]
# ## 1. Check your JupyterHub workspace
#
# Before writing any code:
#
# 1. Find this notebook in the JupyterLab file browser.
# 2. Make your own working copy if instructed to do so.
# 3. Rename your working notebook so that you can recognise it later.
# 4. Save it.
#
# Ask for help now if you cannot find, rename, or save the notebook.

# %% [markdown]
# ## 2. Edit a Markdown cell
#
# Double-click this cell and replace the two placeholders below. Then run the cell with `Shift+Enter` so that it becomes formatted text again.
#
# ### Student: YOUR NAME
#
# I am working in JupyterLab for the first time on: TODAY'S DATE

# %% [markdown]
# ## 3. Run and edit Python code
#
# Run the next code cell. If you see the message underneath it, your Python environment is working.

# %%
print("My Python environment is working!")

# %% [markdown]
# Edit the next cell so that it prints a message of your choice, then run it. Remember to keep the message inside quotation marks.

# %%
print("Replace this text with your own message")

# %% [markdown]
# ## 4. Arithmetic
#
# Replace each `...` with code that performs the requested calculation. Run each cell and check its output.

# %%
# Add 5 and 3
...

# %%
# Multiply 4 by 2
...

# %%
# Subtract 6 from 15
...

# %% [markdown]
# ## 5. Variables
#
# Create the following variables by replacing the `...` placeholders:
#
# - `student_name`, containing your name as text;
# - `week_number`, containing the whole number `1`; and
# - `hours_available`, containing a number with a decimal point.
#
# Text must be placed inside quotation marks.

# %%
student_name = ...
week_number = ...
hours_available = ...

# %% [markdown]
# Complete the next cell so that it prints all three variables.

# %%
print(...)
print(...)
print(...)

# %% [markdown]
# Use `type()` to inspect each variable. Replace the placeholders with the variable names.

# %%
print(type(...))
print(type(...))
print(type(...))

# %% [markdown]
# You should see `str` for text, `int` for the whole number, and `float` for the decimal number. If not, compare your code with the examples in the demonstration notebook.

# %% [markdown]
# ## 6. Lists
#
# Create a list named `snacks` containing three snack names. Each snack name should be a string.

# %%
snacks = [...]
print(snacks)

# %% [markdown]
# Print the first item in your list. Remember that Python starts counting at zero.

# %%
print(snacks[...])

# %% [markdown]
# Print the final item using the index `-1`.

# %%
print(snacks[...])

# %% [markdown]
# Use `len()` to display the number of items in your list.

# %%
print(...(snacks))

# %% [markdown]
# Add one more snack to the end of the list using `.append()`. Then print the updated list and its new length.

# %%
snacks.append(...)
print(...)
print(...(snacks))

# %% [markdown]
# ## 7. Fix a small mistake
#
# The next cell is intended to store the word `finished`, but the quotation marks are missing. Run it once to see the error, then add quotation marks and run it again. Red error messages are a normal part of writing code.

# %%
status = finished
print(status)

# %% [markdown]
# ## 8. Check that your work persists
#
# Complete the message in the next cell by adding todays data and run it. Then:
#
# 1. save the notebook;
# 2. close the within the jupyterlab environment;
# 3. find and reopen it from the JupyterLab file browser; and
# 4. confirm that your completed code and outputs are still present.
# 5. Now close the whole browser window or tab.  Then relogin through moodle and confirm the changes are still present

# %%
persistence_message = "I saved this notebook on ..."
print(persistence_message)

# %% [markdown]
# ## Finished
#
# You have completed the week-one practical if you can:
#
# - find and save your notebook;
# - run Markdown and code cells;
# - use simple variables; and
# - create, inspect, and extend a list.
#
#
# Do not worry if the syntax does not yet feel automatic. The important week-one achievements are gaining access to the environment, saving your work, running cells, and beginning to recognise variables, types, and lists. You will keep practising all of these skills throughout the module.
