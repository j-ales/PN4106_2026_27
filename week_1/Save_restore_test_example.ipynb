# %% [markdown]
# THis is an an example to use for you to test the ability to recover the original version of stuff from the cloud.
#
# In class you will follow along and we will test saving and restoring and deleting.

# %%
#Muck up this code
1+2
# Out:
# 3
